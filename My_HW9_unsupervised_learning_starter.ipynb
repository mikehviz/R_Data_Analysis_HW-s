# %% [markdown]
# <a href="https://colab.research.google.com/github/mikehviz/R_Data_Analysis_HW-s/blob/main/My_HW9_unsupervised_learning_starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Make a copy of this document first, so that you can edit it.
# *   Complete the homework, adding text boxes and/or code boxes as you see fit.

# %%
library(tidyverse) 
install.packages("ggfortify")
library("ggfortify")
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.1 ──
#
# ✔ ggplot2 3.4.0      ✔ purrr   0.3.5
# ✔ tibble  3.1.8      ✔ dplyr   1.0.10
# ✔ tidyr   1.2.1      ✔ stringr 1.4.1
# ✔ readr   2.1.3      ✔ forcats 0.5.2
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘gridExtra’

# %%
mpg
# Out:
#     manufacturer model              displ year cyl trans      drv cty hwy fl
# 1   audi         a4                 1.8   1999 4   auto(l5)   f   18  29  p
# 2   audi         a4                 1.8   1999 4   manual(m5) f   21  29  p
# 3   audi         a4                 2.0   2008 4   manual(m6) f   20  31  p
# 4   audi         a4                 2.0   2008 4   auto(av)   f   21  30  p
# 5   audi         a4                 2.8   1999 6   auto(l5)   f   16  26  p
# 6   audi         a4                 2.8   1999 6   manual(m5) f   18  26  p
# 7   audi         a4                 3.1   2008 6   auto(av)   f   18  27  p
# 8   audi         a4 quattro         1.8   1999 4   manual(m5) 4   18  26  p
# 9   audi         a4 quattro         1.8   1999 4   auto(l5)   4   16  25  p
# 10  audi         a4 quattro         2.0   2008 4   manual(m6) 4   20  28  p
# 11  audi         a4 quattro         2.0   2008 4   auto(s6)   4   19  27  p
# ...

# %% [markdown]
# ## Hierarchical Clustering

# %%
summary(mpg)
# Out:
#  manufacturer          model               displ            year
#  Length:234         Length:234         Min.   :1.600   Min.   :1999
#  Class :character   Class :character   1st Qu.:2.400   1st Qu.:1999
#  Mode  :character   Mode  :character   Median :3.300   Median :2004
#                                        Mean   :3.472   Mean   :2004
#                                        3rd Qu.:4.600   3rd Qu.:2008
#                                        Max.   :7.000   Max.   :2008
#       cyl           trans               drv                 cty
#  Min.   :4.000   Length:234         Length:234         Min.   : 9.00
#  1st Qu.:4.000   Class :character   Class :character   1st Qu.:14.00
#  Median :6.000   Mode  :character   Mode  :character   Median :17.00
#  Mean   :5.889                                         Mean   :16.86
#  3rd Qu.:8.000                                         3rd Qu.:19.00
#  Max.   :8.000                                         Max.   :35.00
# ...

# %% [markdown]
# ###Task 1.
# * Select variables `displ` and `cty` (you can check the meaning of these variables by running `?mpg`)
# * check if there are missing values, if so, remove them
# * scale data
# * compute distance matrix

# %%
colSums(is.na(mpg))

mpg_scale <- mpg %>%
select(displ, cty)

mpgscale <- scale(mpg_scale)
distance_mat <- dist(mpgscale)
# Out:
# manufacturer        model        displ         year          cyl        trans
#            0            0            0            0            0            0
#          drv          cty          hwy           fl        class
#            0            0            0            0            0

# %%
plot.new()
# Out:
# plot without title

# %%
hierar_cl <- hclust(distance_mat)

# %% [markdown]
# ###Task 2.
# * Create a dendrogram.
# * Draw rectangulars to group the cars in a way you see fit

# %%
plot(hierar_cl)
options(repr.plot.height = 6, repr.plot.width = 16)
rect.hclust(hierar_cl, k=3, border = "red")
# Out:
# Plot with title “Cluster Dendrogram”

# %% [markdown]
# ###Task 3. Use `cutree` function to produce k clusters (choose your own k based on the dendrogram)

# %%
fit <- cutree(hierar_cl, h=3)

# %% [markdown]
# ### Task 4.
# * Create a scatterplot of `cty` against `displ`
# * color the dots according to their cluster
# * briefly describe the characteristics of each cluster

# %%
ggplot(mpgscale, aes(displ, cty, color =  fit)) +
  geom_point()
# Out:
# plot without title

# %% [markdown]
# cluster one(upper right) has high cty mileage and low displacement, the opposite can be said for cluster four(far left)
# cluster two(right of cluster one)has higher cty and less displacment in general than cluster three(right of cluster two

# %% [markdown]
# ## K-means Clustering
#
# ###Task 5.
# * again, select `displ` and `cty` from the original `mpg` data
# * check if the result is a data frame
# * if not, make it a data frame

# %%
kmean <- kmeans(mpgscale, 3) 
is.data.frame(mpgscale)
kmean_df <- as.data.frame(mpgscale)
is.data.frame(kmean_df)
# Out:
# [1] FALSE
# [1] TRUE

# %% [markdown]
# ### Task 6.
# *  Use the following function to produce an elbow plot from the data frame you checked above.
# * What seems to be the optimal choice for k?

# %%
elbowplot <- function(data, nc=15, seed=1234){
  wss <- (nrow(data)-1)*sum(apply(data,2,var))
  for (i in 2:nc){
    set.seed(seed)
    wss[i] <- sum(kmeans(data, centers=i)$withinss)}
  plot(1:nc, wss, type="b", xlab="Number of Clusters",
       ylab="Within groups sum of squares")
  wss
}

# %%
elbowplot(mpg_scale, 10)
# Out:
#  [1] 4609.2600 1755.2665 1048.3624  633.7234  454.5726  403.1405  342.1892
#  [8]  279.5460  194.0584  171.9006
# plot without title

# %% [markdown]
# ### Task 7:
# * scale the data first.
# * With your choice of k, run a k-means clustering.
# * get the centroid of each cluster
# * get the size of each cluster

# %%
cty2 <- scale(mpg$cty)
displ2 <-scale(mpg$displ)
mpg_scale <- data.frame(cty2, displ2, mpg$class)



kmean <- kmeans(mpgscale, 2)
kmean$centers

table(kmean$cluster, mpg_scale$mpg.class)
# Out:
#   displ      cty
# 1  0.9521418 -0.8457248
# 2 -0.7617134  0.6765799
#
#     2seater compact midsize minivan pickup subcompact suv
#   1       5       0       4       5     30          7  53
#   2       0      47      37       6      3         28   9

# %% [markdown]
# ### Task 8.
# * Create a scatterplot with cty against displ
# * color according to cluster
# * briefly explain the characteristics of each cluster

# %%
kmean$cluster <- as.factor(kmean$cluster)
ggplot(mpg_scale, aes(displ2, cty2,  color = kmean$cluster)) + 
geom_point()
# Out:
# plot without title

# %% [markdown]
# * cluster 1: big engine, low city mpg
# * cluster 2: small engine, high city mpg
